# %% [markdown]
# <a href="https://colab.research.google.com/github/Irvinventanilla/DATA-WAREHOUSING-LAB-ACTIVITIES/blob/main/15_Identifying_and_Handling_Missing_Values.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
filename = '/content/drive/MyDrive/Irvin/movies_metadata.csv'
df = pd.read_csv(filename)
df
# Out:
# <ipython-input-3-d901e445e55f>:2: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename)
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# ...

# %%
df.columns =['', 'adult',   'belongs_to_collection',    'budget'    ,'genres',  'homepage', 'id',   'imdb_id',  'original_language',    'original_title',   'overview', '...',  'release_date', 'revenue',  'runtime'   ,'spoken_languages',    'status',   'tagline',  'title',    'video',    'vote_average', 'vote_count','','']
df.head()
# Out:
#                                                       adult  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...
# 1  False                                                NaN
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...
# 3  False                                                NaN
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...
#
#   belongs_to_collection                                             budget  \
# 0              30000000  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1              65000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2                     0  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3              16000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     0                     [{'id': 35, 'name': 'Comedy'}]
#
#                                  genres homepage         id imdb_id  \
# 0  http://toystory.disney.com/toy-story      862  tt0114709      en
# ...

# %%
median_age = df['status'].median()
df['status'].fillna(median_age, inplace=True)
df.isna().sum()
# Out:
#                              0
# adult                    40972
# belongs_to_collection        0
# budget                       0
# genres                   37684
# homepage                     0
# id                          17
# imdb_id                     11
# original_language            0
# original_title             954
# overview                     5
# ...                        386
# release_date                 3
# revenue                      3
# runtime                     87
# spoken_languages             6
# status                       0
# tagline                      6
# title                       87
# video                    25054
# vote_average                 6
# vote_count                   6
#                              6
#                              6
# dtype: int64

# %%
df_filter=df['budget']
df_filter.head()
# Out:
# 0    [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1    [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2    [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3    [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                       [{'id': 35, 'name': 'Comedy'}]
# Name: budget, dtype: object

# %%
interest_filter = df['adult']=='True'
df = df.loc[interest_filter, :]
df['adult'].value_counts(dropna = True)
# Out:
# Series([], Name: adult, dtype: int64)

# %%
dp_colm = pd.read_csv('/content/drive/MyDrive/Irvin/movies_metadata.csv',
usecols=['imdb_id', 'adult', 'belongs_to_collection', 'budget', 'original_language', 'original_title'],
index_col='imdb_id')

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: [, adult, belongs_to_collection, budget, genres, homepage, id, imdb_id, original_language, original_title, overview, ..., release_date, revenue, runtime, spoken_languages, status, tagline, title, video, vote_average, vote_count, , ]
# Index: []
#
# [0 rows x 24 columns]

# %%
# Rename the columns
df_rename = dp_colm.rename(columns={
    'imdb_id': 'IMDB ID',
    'adult': 'Adult',
    'belongs_to_collection': 'Collection',
    'budget': 'Budget',
    'original_language': 'Language',
    'original_title': 'Title'
})

# %%
df_rename.head(10)
# Out:
#            Adult                                         Collection    Budget  \
# imdb_id
# tt0114709  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# tt0113497  False                                                NaN  65000000
# tt0113228  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# tt0114885  False                                                NaN  16000000
# tt0113041  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# tt0113277  False                                                NaN  60000000
# tt0114319  False                                                NaN  58000000
# tt0112302  False                                                NaN         0
# tt0114576  False                                                NaN  35000000
# tt0113189  False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
#
#           Language                        Title
# imdb_id
# ...

# %%
df=df.drop(columns=['adult'])
df.head()
# Out:
# Empty DataFrame
# Columns: [, belongs_to_collection, budget, genres, homepage, id, imdb_id, original_language, original_title, overview, ..., release_date, revenue, runtime, spoken_languages, status, tagline, title, video, vote_average, vote_count, , ]
# Index: []
#
# [0 rows x 23 columns]

# %%
del df['original_title']
df.head()
# Out:
# Empty DataFrame
# Columns: [, belongs_to_collection, budget, genres, homepage, id, imdb_id, original_language, overview, ..., release_date, revenue, runtime, spoken_languages, status, tagline, title, video, vote_average, vote_count, , ]
# Index: []
#
# [0 rows x 22 columns]
