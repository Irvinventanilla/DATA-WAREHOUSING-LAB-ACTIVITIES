# %% [markdown]
# <a href="https://colab.research.google.com/github/Irvinventanilla/DATA-WAREHOUSING-LAB-ACTIVITIES/blob/main/17_Groupby.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
filename = '/content/drive/MyDrive/Irvin/FPL_Schedule2324.csv'
df = pd.read_csv(filename)
df
# Out:
#               Team             GW1             GW2             GW3  \
# 0          Arsenal   Nott'm Forest  Crystal Palace          Fulham
# 1      Aston Villa       Newcastle         Everton         Burnley
# 2      Bournemouth        West Ham       Liverpool           Spurs
# 3        Brentford           Spurs          Fulham  Crystal Palace
# 4         Brighton      Luton Town          Wolves        West Ham
# 5          Burnley        Man City      Luton Town     Aston Villa
# 6          Chelsea       Liverpool        West Ham      Luton Town
# 7   Crystal Palace       Sheff Utd         Arsenal       Brentford
# 8          Everton          Fulham     Aston Villa          Wolves
# 9           Fulham         Everton       Brentford         Arsenal
# 10       Liverpool         Chelsea     Bournemouth       Newcastle
# 11      Luton Town        Brighton         Burnley         Chelsea
# 12        Man City         Burnley       Newcastle       Sheff Utd
# ...

# %%
filename = '/content/drive/MyDrive/Irvin/pll-team-stats.csv'
df = pd.read_csv(filename)
df
# Out:
#     season        team  wins  losses  scores_for  scores_against  \
# 0     2019       Chaos     7       3         130             128
# 1     2019  Whipsnakes     6       4         125             116
# 2     2019       Atlas     5       5         125             132
# 3     2019    Redwoods     5       5         116             117
# 4     2019     Archers     5       5         112             106
# 5     2019      Chrome     2       8         127             137
# 6     2020  Whipsnakes     4       0          82              51
# 7     2020     Archers     3       1          64              68
# 8     2020      Chrome     3       1          64              64
# 9     2020    Redwoods     2       2          62              63
# 10    2020   Waterdogs     1       3          47              53
# 11    2020       Atlas     1       3          46              58
# 12    2020       Chaos     0       4          70              78
# ...

# %%
df = pd.read_csv('/content/drive/MyDrive/Irvin/pll-team-stats.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   season                   29 non-null     int64
#  1   team                     29 non-null     object
#  2   wins                     29 non-null     int64
#  3   losses                   29 non-null     int64
#  4   scores_for               29 non-null     int64
#  5   scores_against           29 non-null     int64
#  6   score_differential       29 non-null     int64
#  7   one_point_goals          29 non-null     int64
#  8   two_point_goals          29 non-null     int64
#  9   assists                  29 non-null     int64
#  10  shots                    29 non-null     int64
#  11  shot_percentage          29 non-null     float64
#  12  x2_point_shots           29 non-null     int64
#  13  x2_point_shot_pecentage  29 non-null     float64
# ...

# %%
df.describe().round(2)
# Out:
#         season   wins  losses  scores_for  scores_against  score_differential  \
# count    29.00  29.00   29.00       29.00           29.00               29.00
# mean   2020.62   4.14    4.14      102.83          102.86               -0.03
# std       1.12   2.17    2.17       25.93           26.34               14.65
# min    2019.00   0.00    0.00       46.00           51.00              -29.00
# 25%    2020.00   2.00    3.00       92.00           95.00              -10.00
# 50%    2021.00   5.00    4.00      111.00          108.00               -1.00
# 75%    2022.00   6.00    5.00      120.00          120.00                9.00
# max    2022.00   9.00    9.00      130.00          140.00               31.00
#
#        one_point_goals  two_point_goals  assists   shots  ...  faceoffs_lost  \
# count            29.00            29.00    29.00   29.00  ...          29.00
# mean             90.21             6.31    54.62  345.52  ...         112.52
# ...

# %%
df['season'].mean()
# Out:
# 2020.6206896551723

# %%
df.groupby('team') ['season'].mean()
# Out:
# team
# Archers       2020.5
# Atlas         2020.5
# Cannons       2021.5
# Chaos         2020.5
# Chrome        2020.5
# Redwoods      2020.5
# Waterdogs     2021.0
# Whipsnakes    2020.5
# Name: season, dtype: float64

# %%
df.groupby(['team', 'wins']) ['season'].mean()
# Out:
# team        wins
# Archers     3       2020.0
#             5       2020.0
#             6       2022.0
# Atlas       1       2020.0
#             5       2019.0
#             6       2021.5
# Cannons     1       2022.0
#             3       2021.0
# Chaos       0       2020.0
#             2       2022.0
#             4       2021.0
#             7       2019.0
# Chrome      2       2020.0
#             3       2020.0
#             7       2022.0
# Redwoods    2       2020.0
#             4       2022.0
#             5       2020.0
# Waterdogs   1       2020.0
#             5       2022.0
#             6       2021.0
# Whipsnakes  4       2020.0
#             5       2021.0
#             6       2019.0
#             9       2022.0
# Name: season, dtype: float64
